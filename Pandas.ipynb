# %% [markdown]
# <a href="https://colab.research.google.com/github/Devv07/Pandas_Practice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset={
    'person':['ram','hari','gita','sita'],
    'age' :[20,25,23,19]
}
data =pd.DataFrame(dataset,index=[1,2,3,4])
print(data)
# Out:
#   person  age
# 1    ram   20
# 2   hari   25
# 3   gita   23
# 4   sita   19

# %%
import pandas as pd

arr=[1,2,3,4]
newArr=pd.Series(arr,index=[1,2,3,4])
print(newArr)
print(newArr[2])
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
# 2

# %%
import pandas as pd

data={
    'name':'Yash Mandal',
    'address':'Kathmandu',
    'age':20,
    'phone_num':'9804720452'
}

newData=pd.Series(data,index=['name','age'])
print(newData)
# Out:
# name    Yash Mandal
# age              20
# dtype: object

# %%
import pandas as pd
data={
    'calories':[420,540,290,384],
    'duration':[20,40,50,60],
    'day':['Sunday','Monday','Tuesday','Wednesday']
}

DataSeries=pd.Series(data)
Frame=pd.DataFrame(data)

print(DataSeries)
print('\n',Frame)
print(Frame.loc[[0,1,2,2]])
# Out:
# calories                    [420, 540, 290, 384]
# duration                        [20, 40, 50, 60]
# day         [Sunday, Monday, Tuesday, Wednesday]
# dtype: object
#
#     calories  duration        day
# 0       420        20     Sunday
# 1       540        40     Monday
# 2       290        50    Tuesday
# 3       384        60  Wednesday
#    calories  duration      day
# 0       420        20   Sunday
# 1       540        40   Monday
# 2       290        50  Tuesday
# 2       290        50  Tuesday

# %%
import pandas as pd

df=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(pd.options.display.max_rows)
print(df.to_string())
# Out:
# 60
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  population  households  median_income  median_house_value
# 0       -122.05     37.37                27.0       3885.0           661.0      1537.0       606.0         6.6085            344700.0
# 1       -118.30     34.26                43.0       1510.0           310.0       809.0       277.0         3.5990            176500.0
# 2       -117.81     33.78                27.0       3589.0           507.0      1484.0       495.0         5.7934            270500.0
# 3       -118.36     33.82                28.0         67.0            15.0        49.0        11.0         6.1359            330000.0
# 4       -119.67     36.33                19.0       1241.0           244.0       850.0       237.0         2.9375             81700.0
# 5       -119.56     36.51                37.0       1018.0           213.0       663.0       204.0         1.6635             67000.0
# ...

# %%
import pandas as pd
df=pd.read_json('/content/sample_data/anscombe.json')
print(df.to_string())
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
import pandas as pd

df=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(df.head())
print(df.tail())
print(df.info())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data.csv')

new_df=df.dropna()
print(new_df.to_string())
print("\nThis is a orginal data set :\n",df.to_string())
df.fillna({'Date':'2020/12/22','Calories':300},inplace=True)
print('\n Fill empty value :\n',df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data.csv')

# x=df['Calories'].mean()
# x=df['Calories'].median()
x=df['Calories'].mode()[0]
df.fillna({'Calories':x},inplace=True)
print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data.csv')

df.fillna({'Date':'2020-12-22','Calories':'300.0'},inplace=True)
df['Date']=pd.to_datetime(df['Date'],format='mixed')
# df.loc[7,'Duration']=45   #use for small data set
for x in df.index:          # use for big data set
  if df.loc[x,'Duration']>60:
    df.loc[x,'Duration']=50
    # df.drop(x,inplace=True)  it remove the row form data set
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse Calories
# 0         60 2020-12-01    110       130    409.1
# 1         60 2020-12-02    117       145    479.0
# 2         60 2020-12-03    103       135    340.0
# 3         45 2020-12-04    109       175    282.4
# 4         45 2020-12-05    117       148    406.0
# 5         60 2020-12-06    102       127    300.0
# 6         60 2020-12-07    110       136    374.0
# 7         50 2020-12-08    104       134    253.3
# 8         30 2020-12-09    109       133    195.1
# 9         60 2020-12-10     98       124    269.0
# 10        60 2020-12-11    103       147    329.3
# 11        60 2020-12-12    100       120    250.7
# 12        60 2020-12-12    100       120    250.7
# 13        60 2020-12-13    106       128    345.3
# 14        60 2020-12-14    104       132    379.3
# 15        60 2020-12-15     98       123    275.0
# 16        60 2020-12-16     98       120    215.2
# 17        60 2020-12-17    100       120    300.0
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data.csv')
df.drop_duplicates(inplace=True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/dataNumber.csv')

print(df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
import pandas as pd

data = {
    'Study_Hours': [1, 2, 3, 4, 5],
    'Sleep_Hours': [8, 7, 6, 5, 4],
    'Exam_Score':  [50, 60, 70, 80, 90]
}
df=pd.DataFrame(data,index=[1,2,3,4,5])
print(df,'\n'),
print(df.corr())
# Out:
#    Study_Hours  Sleep_Hours  Exam_Score
# 1            1            8          50
# 2            2            7          60
# 3            3            6          70
# 4            4            5          80
# 5            5            4          90
#
#              Study_Hours  Sleep_Hours  Exam_Score
# Study_Hours          1.0         -1.0         1.0
# Sleep_Hours         -1.0          1.0        -1.0
# Exam_Score           1.0         -1.0         1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/sample_data/data.csv')

df.plot()
plt.show()

# %%
import matplotlib.pyplot as plt

data = [55, 65, 60, 70, 75, 80, 85, 90, 95, 100]
plt.hist(data, bins=5)
plt.title("Student Score Distribution")
plt.xlabel("Score Range")
plt.ylabel("Number of Students")
plt.show()

# %%
import matplotlib.pyplot as plt

data = [2, 5, 10, 20, 30, 8, 7]
bins = 6

plt.hist(data, bins=bins, edgecolor='black')
plt.title("Histogram with 3 Bins")
plt.xlabel("Data Range")
plt.ylabel("Frequency (Count)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/sample_data/data.csv')

df['Pulse'].plot(kind='hist')
print(df)
plt.show()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('/content/sample_data/bank_messy_data.csv')
df
# Out:
#       Account_ID Customer_Name   Age  Gender   Balance Last_Transaction_Date  \
# 0       ACC-1000         Frank    61    Male  43891.54            2023-07-02
# 1       ACC-1001          Ivan    20    Male  41137.43            2023-07-12
# 2       ACC-1002          Judy    34    Male  27189.46            2023-10-14
# 3       ACC-1003          Ivan    60    Male  22426.02            2023-02-07
# 4    ###ERROR###         Grace    70    Male  14242.55            2023-07-24
# ..           ...           ...   ...     ...       ...                   ...
# 545     ACC-1545       Charlie  age?    Male  37838.07            2023-02-21
# 546     ACC-1546          Judy    38  Female  39786.88            2023-11-14
# 547     ACC-1547         Frank    57   Other  40046.08            2023-11-23
# 548     ACC-1548          Ivan    67   Other  23160.25            2023-06-09
# 549     ACC-1549         David    83   Other   6700.41            date_error
#
# ...

# %%
print(df.dtypes)
# Out:
# Account_ID                object
# Customer_Name             object
# Age                       object
# Gender                    object
# Balance                  float64
# Last_Transaction_Date     object
# Branch                    object
# Status                    object
# Phone                     object
# Email                     object
# dtype: object

# %%
data=pd.to_datetime(df(['Account_ID']),errors='coerce')
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-865091927.py in <cell line: 0>()
# ----> 1 data=pd.to_datetime(df(['Account_ID']),errors='coerce')
#       2 print(data)
#
# TypeError: 'DataFrame' object is not callable

# %%
invalied=df[
    pd.to_numeric(df['Account_ID'],errors='coerce').isna() &
    df['Account_ID'].notna()&
    (df['Account_ID'].str.strip()!='')
    ]  # it show the wrong format data
print(invalied)
# Out:
#       Account_ID Customer_Name   Age  Gender   Balance Last_Transaction_Date  \
# 0       ACC-1000         Frank    61    Male  43891.54            2023-07-02
# 1       ACC-1001          Ivan    20    Male  41137.43            2023-07-12
# 2       ACC-1002          Judy    34    Male  27189.46            2023-10-14
# 3       ACC-1003          Ivan    60    Male  22426.02            2023-02-07
# 4    ###ERROR###         Grace    70    Male  14242.55            2023-07-24
# ..           ...           ...   ...     ...       ...                   ...
# 545     ACC-1545       Charlie  age?    Male  37838.07            2023-02-21
# 546     ACC-1546          Judy    38  Female  39786.88            2023-11-14
# 547     ACC-1547         Frank    57   Other  40046.08            2023-11-23
# 548     ACC-1548          Ivan    67   Other  23160.25            2023-06-09
# 549     ACC-1549         David    83   Other   6700.41            date_error
#
# ...

# %%
data=pd.read_csv('/content/sample_data/data.csv')
print(data)
print(data.dtypes)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(data.columns)
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data=pd.read_csv('/content/sample_data/data.csv')

null = data[data['Date'].isna()]
calories=data[pd.to_numeric(data['Calories'],errors='coerce').isna()]

print(null)
print('\n')
print(calories)
# Out:
#     Duration Date  Pulse  Maxpulse  Calories
# 22        45  NaN    100       119     282.0
#
#
#     Duration          Date  Pulse  Maxpulse  Calories
# 18        45  '2020/12/18'     90       112       NaN
# 28        60  '2020/12/28'    103       132       NaN

# %%
wrong=data.select_dtypes(include='float64').isnull().sum()
print(wrong)
# Out:
# Calories    2
# dtype: int64

# %%
data['Calories'].fillna(data['Calories'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-12-1009356683.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Calories'].fillna(data['Calories'].mode()[0],inplace=True)

# %%
print(data['Calories'].isna().sum())  # Should print 0 after fillna
# Out:
# 0

# %%
print(data)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_csv("/content/sample_data/data.csv")
data['Date']=pd.to_datetime(data['Date'],errors='coerce')
data['Date']=data['Date'].fillna(pd.Timestamp('2025/12/22'))     #fill the missing data

# %%
data['Calories'].fillna(data['Calories'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-17-1009356683.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Calories'].fillna(data['Calories'].mode()[0],inplace=True)

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
data.loc[7, 'Duration']=45

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

invalied=data.isna().sum()
print(invalied)
sns.heatmap(data.isnull())
plt.show()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
